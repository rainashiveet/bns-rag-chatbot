# %%
# !pip install streamlit
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 3.0.1
#     Uninstalling pandas-3.0.1:
#       Successfully uninstalled pandas-3.0.1
# ...
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'D:\Python_anoconda\Lib\site-packages\~-ndas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'D:\Python_anoconda\Lib\site-packages\~~ndas'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
