# %% [markdown]
# # Install libraries

# %%
# !pip install langchain
# !pip install langchain-community
# !pip install langchain-huggingface
# !pip install chromadb
# !pip install sentence-transformers
# !pip install pypdf
# Out:
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# Requirement already satisfied: langchain in D:\Python_anoconda\Lib\site-packages (1.2.12)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in D:\Python_anoconda\Lib\site-packages (from langchain) (1.2.18)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in D:\Python_anoconda\Lib\site-packages (from langchain) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in D:\Python_anoconda\Lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.6.5)
# Requirement already satisfied: packaging>=23.2.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\Python_anoconda\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in D:\Python_anoconda\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in D:\Python_anoconda\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in D:\Python_anoconda\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in D:\Python_anoconda\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in D:\Python_anoconda\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in D:\Python_anoconda\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in D:\Python_anoconda\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.23.0)
# Requirement already satisfied: anyio in D:\Python_anoconda\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.12.1)
# Requirement already satisfied: certifi in D:\Python_anoconda\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in D:\Python_anoconda\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in D:\Python_anoconda\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in D:\Python_anoconda\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Python_anoconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in D:\Python_anoconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Python_anoconda\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\Python_anoconda\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.3.0)
# Requirement already satisfied: langchain-community in D:\Python_anoconda\Lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (1.2.18)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (3.11.10)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (0.6.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in D:\Python_anoconda\Lib\site-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in D:\Python_anoconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in D:\Python_anoconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in D:\Python_anoconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in D:\Python_anoconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in D:\Python_anoconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in D:\Python_anoconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in D:\Python_anoconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in D:\Python_anoconda\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in D:\Python_anoconda\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in D:\Python_anoconda\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in D:\Python_anoconda\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\Python_anoconda\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: certifi in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.7)
# Requirement already satisfied: h11>=0.16 in D:\Python_anoconda\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Python_anoconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in D:\Python_anoconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in D:\Python_anoconda\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in D:\Python_anoconda\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Python_anoconda\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\Python_anoconda\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in D:\Python_anoconda\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in D:\Python_anoconda\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# Requirement already satisfied: langchain-huggingface in D:\Python_anoconda\Lib\site-packages (1.2.1)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in D:\Python_anoconda\Lib\site-packages (from langchain-huggingface) (1.5.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in D:\Python_anoconda\Lib\site-packages (from langchain-huggingface) (1.2.18)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in D:\Python_anoconda\Lib\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: filelock>=3.10.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.67.3)
# Requirement already satisfied: typer in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.12.2)
# Requirement already satisfied: anyio in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.12.1)
# Requirement already satisfied: certifi in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.7)
# Requirement already satisfied: h11>=0.16 in D:\Python_anoconda\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.6.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (9.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\Python_anoconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\Python_anoconda\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.1)
# Requirement already satisfied: orjson>=3.9.14 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in D:\Python_anoconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Python_anoconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in D:\Python_anoconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Python_anoconda\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\Python_anoconda\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-huggingface) (2.3.0)
# Requirement already satisfied: colorama in D:\Python_anoconda\Lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in D:\Python_anoconda\Lib\site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.1.8)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# Requirement already satisfied: chromadb in D:\Python_anoconda\Lib\site-packages (1.4.1)
# Requirement already satisfied: build>=1.0.3 in D:\Python_anoconda\Lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pydantic>=1.9 in D:\Python_anoconda\Lib\site-packages (from chromadb) (2.10.3)
# Requirement already satisfied: pybase64>=1.4.1 in D:\Python_anoconda\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in D:\Python_anoconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.40.0)
# Requirement already satisfied: numpy>=1.22.5 in D:\Python_anoconda\Lib\site-packages (from chromadb) (2.1.3)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in D:\Python_anoconda\Lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in D:\Python_anoconda\Lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in D:\Python_anoconda\Lib\site-packages (from chromadb) (0.50.0)
# Requirement already satisfied: tqdm>=4.65.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in D:\Python_anoconda\Lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in D:\Python_anoconda\Lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in D:\Python_anoconda\Lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in D:\Python_anoconda\Lib\site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in D:\Python_anoconda\Lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in D:\Python_anoconda\Lib\site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in D:\Python_anoconda\Lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: requests<3.0,>=2.7 in D:\Python_anoconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in D:\Python_anoconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in D:\Python_anoconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in D:\Python_anoconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in D:\Python_anoconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Python_anoconda\Lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in D:\Python_anoconda\Lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\Python_anoconda\Lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in D:\Python_anoconda\Lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.8.3)
# Requirement already satisfied: packaging>=24.0 in D:\Python_anoconda\Lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in D:\Python_anoconda\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in D:\Python_anoconda\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in D:\Python_anoconda\Lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.1)
# Requirement already satisfied: httpcore==1.* in D:\Python_anoconda\Lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\Python_anoconda\Lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in D:\Python_anoconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in D:\Python_anoconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in D:\Python_anoconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in D:\Python_anoconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in D:\Python_anoconda\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in D:\Python_anoconda\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in D:\Python_anoconda\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in D:\Python_anoconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in D:\Python_anoconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in D:\Python_anoconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in D:\Python_anoconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in D:\Python_anoconda\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in D:\Python_anoconda\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in D:\Python_anoconda\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in D:\Python_anoconda\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in D:\Python_anoconda\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in D:\Python_anoconda\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Python_anoconda\Lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in D:\Python_anoconda\Lib\site-packages (from pydantic>=1.9->chromadb) (2.27.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\Python_anoconda\Lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\Python_anoconda\Lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in D:\Python_anoconda\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in D:\Python_anoconda\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.5.0)
# Requirement already satisfied: filelock>=3.10.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in D:\Python_anoconda\Lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: httptools>=0.6.3 in D:\Python_anoconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in D:\Python_anoconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in D:\Python_anoconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in D:\Python_anoconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in D:\Python_anoconda\Lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in D:\Python_anoconda\Lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in D:\Python_anoconda\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in D:\Python_anoconda\Lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# Requirement already satisfied: sentence-transformers in D:\Python_anoconda\Lib\site-packages (5.2.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in D:\Python_anoconda\Lib\site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in D:\Python_anoconda\Lib\site-packages (from sentence-transformers) (1.5.0)
# Requirement already satisfied: torch>=1.11.0 in D:\Python_anoconda\Lib\site-packages (from sentence-transformers) (2.10.0+cpu)
# Requirement already satisfied: numpy in D:\Python_anoconda\Lib\site-packages (from sentence-transformers) (2.1.3)
# Requirement already satisfied: scikit-learn in D:\Python_anoconda\Lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in D:\Python_anoconda\Lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in D:\Python_anoconda\Lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: tqdm in D:\Python_anoconda\Lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in D:\Python_anoconda\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in D:\Python_anoconda\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in D:\Python_anoconda\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in D:\Python_anoconda\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in D:\Python_anoconda\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.9.0)
# Requirement already satisfied: safetensors>=0.4.3 in D:\Python_anoconda\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\Python_anoconda\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in D:\Python_anoconda\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in D:\Python_anoconda\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in D:\Python_anoconda\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in D:\Python_anoconda\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in D:\Python_anoconda\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in D:\Python_anoconda\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in D:\Python_anoconda\Lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in D:\Python_anoconda\Lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\Python_anoconda\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in D:\Python_anoconda\Lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in D:\Python_anoconda\Lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in D:\Python_anoconda\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.1.8)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# Requirement already satisfied: pypdf in D:\Python_anoconda\Lib\site-packages (6.6.2)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (D:\Python_anoconda\Lib\site-packages)

# %% [markdown]
# # Imports

# %%
from pathlib import Path

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %% [markdown]
# # Paths

# %%
PROJECT_DIR = Path("..").resolve()

DATA_DIR = PROJECT_DIR / "data"

print(DATA_DIR)
# Out:
# C:\Users\raina\bns-rag-chatbot\data

# %% [markdown]
# # Load PDFs

# %%
documents = []

for pdf in DATA_DIR.glob("*.pdf"):
    loader = PyPDFLoader(str(pdf))
    docs = loader.load()
    documents.extend(docs)

print("Total pages loaded:", len(documents))
# Out:
# Total pages loaded: 351

# %% [markdown]
# # Chunk Documents

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=100
)

chunks = text_splitter.split_documents(documents)

print("Total chunks created:", len(chunks))
# Out:
# Total chunks created: 1966
